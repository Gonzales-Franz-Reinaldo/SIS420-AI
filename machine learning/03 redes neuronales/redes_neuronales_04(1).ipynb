# %% [markdown]
# # EJEMPLO - RED NEURONAL PARA DIAGNOSTICO DE LA DIABETES DE PIMA INDIANS
#
# Este ejemplo considera los siguientes objetivos:
# - Cargar datos desde un archivo CSV para usar con Keras.
# - Definir y compilar un modelo de Perceptron multicapa en Keras.
# - Evaluar un modelo Keras en un conjunto de datos de validación.
#
# Los pasos para poder crear este modelo, son los siguientes:
# 1. Cargar datos.
# 2. Definir el Modelo.
# 3. Compilar el Modelo.
# 4. Entrenar el Modelo.
# 5. Evaluar el Modelo.
# 6. Unir todos los pasos anteriores.
#
# ## Cargar datos
# ### Datasets
# Se utilizara un dataset de la Universidad de California Irvine (Diabetes de Pima Indians). Este dataset es un conjunto de datos disponible de manera gratuita desde el repositorio UCI Machine Learning. Describe los datos de registros médicos de los pacientes de de Pima y describe si ellos tuvieron diabetes dentro de un periodo de cinco años. Es un problema de clasificación binaria (aparición de diabetes como 1 o no como 0). Las variables de entrada que describen a cada paciente son numéricas y tienen escalas variables. A continuación se enumeran los ocho atributos para el conjunto de datos:
# 1. Número de veces embarazada.
# 2. Concentración de glucosa plasmática a 2 horas en una prueba oral de tolerancia a la glucosa.
# 3. Presión arterial diastólica (mm Hg).
# 4. Grosor del pliegue de la piel del tríceps (mm).
# 5. Insulina en suero de 2 horas (mu U / ml).
# 6. Índice de masa corporal.
# 7. Función de pedigrí de diabetes.
# 8. Edad (años).
# 9. Clase, aparición de diabetes dentro de los cinco años.
# Debido a que todos los atributos son numericos, es facil utilizarlos directo en la red neuronal. Este dataset contiene 768 registros.
# La precisión base de todas las predicciones que se realizan es del 65.1%. Los mejores resultados se encuentran en el rango de 77.7% de precisión utilizando 10-fold cross validation.
#
# ### Cargar dataset
# En el siguiente código, se importan las librerias de Keras y numpy.
# Debido a que todos los datos son numéricos, se puede importar el archivo directo con numpy.
# También se inicia el generador aleatorio con la variable seed, para que siempre obtengamos los mismos resultados.

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy

seed = 7
numpy.random.seed(seed)

# Cargar el dataset de los indios Pima.
dataset = numpy.loadtxt("Datasets\pima-indians-diabetes.csv", delimiter=",")

# Dividir los datos en features y label.
X = dataset[:, 0:8]
Y = dataset[:, 8]

# %% [markdown]
# ### Definir el modelo
# Los modelos en Keras son definidos como una sequencias de capas. Podemos crear un modelo sequencia (Sequencial) y agregar capas una a una hasta que cumplan nuestros requerimientos.
# El primer paso es asegurarnos que la primer capa tenga el numero correcto de entradas. Esto se consigue con el argumento input_dim, en este caso utilizaremos el valor de 8 debido a que son 8 variables que se alimentaran en la capa de entrada.
# ¿Cómo saber el numero de capas y sus tipos? Esta es una pregunta complicada pero normalmente se experimenta y a prueba y error se puede llegar a un resultado óptimo. En este caso vamos a utilizar una red conectada completamente con 3 capas.
# Capas completamente conectadas son definidas mediante la clase Dense. En esta clase se define el numero de neuronas como primer argumento, como segundo argumento se define el método de inicialización, y la función de activación. En este caso vamos a iniciar los pesos de la red con un valor aleatorio muy pequeño utilizando una distribución uniforme (uniform), en Keras el valor va de 0 a 0.05. Otra opción seria utilizar una distribución de Gauss (normal).
# En las primeras dos capas se definirá una función de activación relu y para la capa de salida una función sigmoid. En el pasado las funciones sigmoid y tanh eran las utilizadas en todas las capas, pero ha sido demostrado que el desempeño mejora utilizando la función rectifier como activación. En nuestro caso utilizamos la función sigmoid en la capada de salida para asegurarnos que el valor de salido oscila entre 0 y 1 y es mas fácil definir el resultado en la clasificación binaria.

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 12)                108
# _________________________________________________________________
# dense_14 (Dense)             (None, 8)                 104
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compilar el modelo
# Una vez que el modelo esta definido, se procede a compilarlo. Al compilar el modelo se mandan llamar las librerias en el backend, en nuestro caso Tensorflow. En este caso el backend automáticamente selecciona la mejor forma de representar la red neuronal para entrenamiento y realizar predicciones en el hardware. Cuando se compila el modelo, se deben definir algunas propiedades adicionales requeridas para el entrenamiento del modelo:
# Especifica la función de perdida o loss function, que es utilizada para evaluar los pesos. También debes definir el optimizador utilizado para buscar entre los pesos de la red y algunas métricas opcionales que se require colectar y reportar durante el entrenamiento. En este ejemplo utilizaremos una función de perdida binary_crossentropy, que es una función logarítmica de perdida. Se utilizará una función para los calcular los gradientes llamada adam. Al ser un problema de clasificación binaria, se coleccionará y reportará la precision de la clasificación utilizando accuracy.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### Entrenar el modelo
# Una vez que este definido y compilado el modelo, es tiempo de ejecutar el modelo con los datos. Se entrena el modelo llamando la función fit() en el modelo.
# El proceso de entrenamiento se ejecuta cierto numero de veces utilizando el dataset, este numero de veces es llamado epochs, y se define utilizando el parámetro nb_epoch. También podemos definir el numero de instances que son evaluadas antes de que los pesos sean actualizados en la red neuronal. Este parámetro se llama batch_size. En este problema se definirá un numero pequeño de epochs (150) y un valor relativamente pequeño de el batch (10).

# %%
model.fit(X, Y, epochs=150, batch_size=50)

#model.fit(X, Y, epochs=50, batch_size=250, verbose=2, validation_split=0.2)
# Out:
# Epoch 1/150
# 768/768 [==============================] - 0s 251us/step - loss: 4.6291 - accuracy: 0.4271
# Epoch 2/150
# 768/768 [==============================] - 0s 31us/step - loss: 2.1701 - accuracy: 0.5807
# Epoch 3/150
# 768/768 [==============================] - 0s 35us/step - loss: 1.6793 - accuracy: 0.6198
# Epoch 4/150
# 768/768 [==============================] - 0s 37us/step - loss: 1.6015 - accuracy: 0.5990
# Epoch 5/150
# 768/768 [==============================] - 0s 41us/step - loss: 1.4880 - accuracy: 0.6120
# Epoch 6/150
# 768/768 [==============================] - 0s 34us/step - loss: 1.4049 - accuracy: 0.6224
# Epoch 7/150
# 768/768 [==============================] - 0s 44us/step - loss: 1.3331 - accuracy: 0.6016
# Epoch 8/150
# 768/768 [==============================] - 0s 34us/step - loss: 1.2356 - accuracy: 0.6354
# Epoch 9/150
# 768/768 [==============================] - 0s 35us/step - loss: 1.1673 - accuracy: 0.6393
# Epoch 10/150
# 768/768 [==============================] - 0s 37us/step - loss: 1.1322 - accuracy: 0.6523
# Epoch 11/150
# 768/768 [==============================] - 0s 42us/step - loss: 1.0781 - accuracy: 0.6367
# Epoch 12/150
# 768/768 [==============================] - 0s 43us/step - loss: 1.0072 - accuracy: 0.6549
# Epoch 13/150
# 768/768 [==============================] - 0s 38us/step - loss: 0.9421 - accuracy: 0.6562
# Epoch 14/150
# 768/768 [==============================] - 0s 35us/step - loss: 0.8910 - accuracy: 0.6536
# Epoch 15/150
# 768/768 [==============================] - 0s 34us/step - loss: 0.8571 - accuracy: 0.6549
# Epoch 16/150
# 768/768 [==============================] - 0s 45us/step - loss: 0.7971 - accuracy: 0.6510
# Epoch 17/150
# 768/768 [==============================] - 0s 43us/step - loss: 0.7553 - accuracy: 0.6680
# Epoch 18/150
# 768/768 [==============================] - 0s 45us/step - loss: 0.7222 - accuracy: 0.6602
# Epoch 19/150
# 768/768 [==============================] - 0s 39us/step - loss: 0.6966 - accuracy: 0.6719
# Epoch 20/150
# 768/768 [==============================] - 0s 39us/step - loss: 0.6858 - accuracy: 0.6810
# Epoch 21/150
# 768/768 [==============================] - 0s 48us/step - loss: 0.6801 - accuracy: 0.6797
# Epoch 22/150
# 768/768 [==============================] - 0s 58us/step - loss: 0.6753 - accuracy: 0.6745
# Epoch 23/150
# 768/768 [==============================] - 0s 60us/step - loss: 0.6686 - accuracy: 0.6771
# Epoch 24/150
# 768/768 [==============================] - 0s 36us/step - loss: 0.6722 - accuracy: 0.6758
# Epoch 25/150
# 768/768 [==============================] - 0s 36us/step - loss: 0.6677 - accuracy: 0.6745
# Epoch 26/150
# 768/768 [==============================] - 0s 49us/step - loss: 0.6682 - accuracy: 0.6758
# Epoch 27/150
# 768/768 [==============================] - 0s 45us/step - loss: 0.6669 - accuracy: 0.6771
# Epoch 28/150
# 768/768 [==============================] - 0s 48us/step - loss: 0.6706 - accuracy: 0.6680
# Epoch 29/150
# 768/768 [==============================] - 0s 32us/step - loss: 0.6634 - accuracy: 0.6719
# Epoch 30/150
# 768/768 [==============================] - 0s 42us/step - loss: 0.6633 - accuracy: 0.6719
# Epoch 31/150
# 768/768 [==============================] - 0s 42us/step - loss: 0.6618 - accuracy: 0.6745
# Epoch 32/150
# 768/768 [==============================] - 0s 43us/step - loss: 0.6601 - accuracy: 0.6758
# Epoch 33/150
# 768/768 [==============================] - 0s 56us/step - loss: 0.6561 - accuracy: 0.6732
# Epoch 34/150
# 768/768 [==============================] - 0s 42us/step - loss: 0.6576 - accuracy: 0.6667
# Epoch 35/150
# 768/768 [==============================] - 0s 37us/step - loss: 0.6579 - accuracy: 0.6693
# Epoch 36/150
# 768/768 [==============================] - 0s 52us/step - loss: 0.6528 - accuracy: 0.6680
# Epoch 37/150
# 768/768 [==============================] - 0s 59us/step - loss: 0.6513 - accuracy: 0.6706
# Epoch 38/150
# 768/768 [==============================] - 0s 48us/step - loss: 0.6527 - accuracy: 0.6719
# Epoch 39/150
# 768/768 [==============================] - 0s 44us/step - loss: 0.6526 - accuracy: 0.6719
# Epoch 40/150
# 768/768 [==============================] - 0s 42us/step - loss: 0.6574 - accuracy: 0.6654
# Epoch 41/150
# 768/768 [==============================] - 0s 47us/step - loss: 0.6552 - accuracy: 0.6693
# Epoch 42/150
# 768/768 [==============================] - 0s 49us/step - loss: 0.6767 - accuracy: 0.6667
# Epoch 43/150
# 768/768 [==============================] - 0s 55us/step - loss: 0.6541 - accuracy: 0.6680
# Epoch 44/150
# 768/768 [==============================] - 0s 50us/step - loss: 0.6412 - accuracy: 0.6680
# Epoch 45/150
# 768/768 [==============================] - 0s 51us/step - loss: 0.6389 - accuracy: 0.6680
# Epoch 46/150
# 768/768 [==============================] - 0s 48us/step - loss: 0.6358 - accuracy: 0.6732
# Epoch 47/150
# 768/768 [==============================] - 0s 58us/step - loss: 0.6372 - accuracy: 0.6693
# Epoch 48/150
# 768/768 [==============================] - 0s 58us/step - loss: 0.6351 - accuracy: 0.6732
# Epoch 49/150
# 768/768 [==============================] - 0s 48us/step - loss: 0.6566 - accuracy: 0.6680
# Epoch 50/150
# 768/768 [==============================] - 0s 57us/step - loss: 0.6564 - accuracy: 0.6654
# Epoch 51/150
# 768/768 [==============================] - 0s 45us/step - loss: 0.6342 - accuracy: 0.6732
# Epoch 52/150
# 768/768 [==============================] - 0s 62us/step - loss: 0.6387 - accuracy: 0.6706
# Epoch 53/150
# 768/768 [==============================] - 0s 53us/step - loss: 0.6389 - accuracy: 0.6719
# Epoch 54/150
# 768/768 [==============================] - 0s 57us/step - loss: 0.6391 - accuracy: 0.6706
# Epoch 55/150
# 768/768 [==============================] - 0s 57us/step - loss: 0.6313 - accuracy: 0.6797
# Epoch 56/150
# 768/768 [==============================] - ETA: 0s - loss: 0.6874 - accuracy: 0.64 - 0s 47us/step - loss: 0.6336 - accuracy: 0.6810
# Epoch 57/150
# 768/768 [==============================] - 0s 64us/step - loss: 0.6379 - accuracy: 0.6771
# Epoch 58/150
# 768/768 [==============================] - 0s 53us/step - loss: 0.6333 - accuracy: 0.6810
# Epoch 59/150
# 768/768 [==============================] - 0s 69us/step - loss: 0.6317 - accuracy: 0.6810
# Epoch 60/150
# 768/768 [==============================] - 0s 50us/step - loss: 0.6324 - accuracy: 0.6771
# Epoch 61/150
# 768/768 [==============================] - 0s 45us/step - loss: 0.6307 - accuracy: 0.6797
# Epoch 62/150
# 768/768 [==============================] - 0s 57us/step - loss: 0.6324 - accuracy: 0.6758
# Epoch 63/150
# 768/768 [==============================] - 0s 60us/step - loss: 0.6293 - accuracy: 0.6784
# Epoch 64/150
# 768/768 [==============================] - 0s 64us/step - loss: 0.6295 - accuracy: 0.6784
# Epoch 65/150
# 768/768 [==============================] - 0s 60us/step - loss: 0.6323 - accuracy: 0.6784
# Epoch 66/150
# 768/768 [==============================] - 0s 57us/step - loss: 0.6282 - accuracy: 0.6836
# Epoch 67/150
# 768/768 [==============================] - 0s 60us/step - loss: 0.6230 - accuracy: 0.6797
# Epoch 68/150
# 768/768 [==============================] - 0s 49us/step - loss: 0.6236 - accuracy: 0.6758
# Epoch 69/150
# 768/768 [==============================] - 0s 47us/step - loss: 0.6335 - accuracy: 0.6810
# Epoch 70/150
# 768/768 [==============================] - 0s 47us/step - loss: 0.6288 - accuracy: 0.6771
# Epoch 71/150
# 768/768 [==============================] - 0s 44us/step - loss: 0.6242 - accuracy: 0.6836
# Epoch 72/150
# 768/768 [==============================] - 0s 52us/step - loss: 0.6352 - accuracy: 0.6836
# Epoch 73/150
# 768/768 [==============================] - 0s 86us/step - loss: 0.6389 - accuracy: 0.6810
# Epoch 74/150
# 768/768 [==============================] - 0s 60us/step - loss: 0.6268 - accuracy: 0.6810
# Epoch 75/150
# 768/768 [==============================] - 0s 64us/step - loss: 0.6298 - accuracy: 0.6758
# Epoch 76/150
# 768/768 [==============================] - 0s 47us/step - loss: 0.6281 - accuracy: 0.6797
# Epoch 77/150
# 768/768 [==============================] - 0s 39us/step - loss: 0.6259 - accuracy: 0.6823
# Epoch 78/150
# 768/768 [==============================] - 0s 42us/step - loss: 0.6238 - accuracy: 0.6784
# Epoch 79/150
# 768/768 [==============================] - 0s 53us/step - loss: 0.6222 - accuracy: 0.6875
# Epoch 80/150
# 768/768 [==============================] - 0s 42us/step - loss: 0.6228 - accuracy: 0.6875
# Epoch 81/150
# 768/768 [==============================] - 0s 51us/step - loss: 0.6263 - accuracy: 0.6875
# Epoch 82/150
# 768/768 [==============================] - 0s 37us/step - loss: 0.6323 - accuracy: 0.6784
# Epoch 83/150
# 768/768 [==============================] - 0s 36us/step - loss: 0.6165 - accuracy: 0.6888
# Epoch 84/150
# 768/768 [==============================] - 0s 48us/step - loss: 0.6319 - accuracy: 0.6823
# Epoch 85/150
# 768/768 [==============================] - 0s 39us/step - loss: 0.6188 - accuracy: 0.6823
# Epoch 86/150
# 768/768 [==============================] - 0s 50us/step - loss: 0.6257 - accuracy: 0.6914
# Epoch 87/150
# 768/768 [==============================] - 0s 38us/step - loss: 0.6157 - accuracy: 0.6862
# Epoch 88/150
# 768/768 [==============================] - 0s 46us/step - loss: 0.6152 - accuracy: 0.6888
# Epoch 89/150
# 768/768 [==============================] - 0s 40us/step - loss: 0.6152 - accuracy: 0.6927
# Epoch 90/150
# 768/768 [==============================] - ETA: 0s - loss: 0.6406 - accuracy: 0.66 - 0s 44us/step - loss: 0.6184 - accuracy: 0.6862
# Epoch 91/150
# 768/768 [==============================] - 0s 41us/step - loss: 0.6269 - accuracy: 0.6810
# Epoch 92/150
# 768/768 [==============================] - 0s 33us/step - loss: 0.6412 - accuracy: 0.6849
# Epoch 93/150
# 768/768 [==============================] - 0s 34us/step - loss: 0.6197 - accuracy: 0.6888
# Epoch 94/150
# 768/768 [==============================] - 0s 36us/step - loss: 0.6171 - accuracy: 0.6875
# Epoch 95/150
# 768/768 [==============================] - 0s 38us/step - loss: 0.6171 - accuracy: 0.6784
# Epoch 96/150
# 768/768 [==============================] - 0s 39us/step - loss: 0.6094 - accuracy: 0.6875
# Epoch 97/150
# 768/768 [==============================] - 0s 32us/step - loss: 0.6348 - accuracy: 0.6849
# Epoch 98/150
# 768/768 [==============================] - 0s 33us/step - loss: 0.6281 - accuracy: 0.6849
# Epoch 99/150
# 768/768 [==============================] - 0s 33us/step - loss: 0.6162 - accuracy: 0.6901
# Epoch 100/150
# 768/768 [==============================] - 0s 33us/step - loss: 0.6115 - accuracy: 0.6862
# Epoch 101/150
# 768/768 [==============================] - 0s 37us/step - loss: 0.6247 - accuracy: 0.6823
# Epoch 102/150
# 768/768 [==============================] - 0s 41us/step - loss: 0.6154 - accuracy: 0.6966
# Epoch 103/150
# 768/768 [==============================] - 0s 32us/step - loss: 0.6119 - accuracy: 0.6927
# Epoch 104/150
# 768/768 [==============================] - 0s 31us/step - loss: 0.6165 - accuracy: 0.6862
# Epoch 105/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.6241 - accuracy: 0.6875
# Epoch 106/150
# 768/768 [==============================] - 0s 31us/step - loss: 0.6097 - accuracy: 0.6875
# Epoch 107/150
# 768/768 [==============================] - 0s 31us/step - loss: 0.6103 - accuracy: 0.6862
# Epoch 108/150
# 768/768 [==============================] - 0s 48us/step - loss: 0.6044 - accuracy: 0.6940
# Epoch 109/150
# 768/768 [==============================] - 0s 34us/step - loss: 0.6134 - accuracy: 0.6927
# Epoch 110/150
# 768/768 [==============================] - 0s 35us/step - loss: 0.6158 - accuracy: 0.6875
# Epoch 111/150
# 768/768 [==============================] - 0s 27us/step - loss: 0.6067 - accuracy: 0.6888
# Epoch 112/150
# 768/768 [==============================] - 0s 31us/step - loss: 0.6085 - accuracy: 0.6927
# Epoch 113/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.6514 - accuracy: 0.6758
# Epoch 114/150
# 768/768 [==============================] - 0s 38us/step - loss: 0.6161 - accuracy: 0.6849
# Epoch 115/150
# 768/768 [==============================] - 0s 36us/step - loss: 0.6091 - accuracy: 0.6901
# Epoch 116/150
# 768/768 [==============================] - 0s 29us/step - loss: 0.6046 - accuracy: 0.6914
# Epoch 117/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.6163 - accuracy: 0.6875
# Epoch 118/150
# 768/768 [==============================] - 0s 27us/step - loss: 0.6333 - accuracy: 0.6758
# Epoch 119/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.6126 - accuracy: 0.6901
# Epoch 120/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.6198 - accuracy: 0.6836
# Epoch 121/150
# 768/768 [==============================] - 0s 42us/step - loss: 0.5933 - accuracy: 0.6992
# Epoch 122/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.6009 - accuracy: 0.6862
# Epoch 123/150
# 768/768 [==============================] - 0s 31us/step - loss: 0.6079 - accuracy: 0.6823
# Epoch 124/150
# 768/768 [==============================] - 0s 27us/step - loss: 0.6059 - accuracy: 0.6823
# Epoch 125/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.5982 - accuracy: 0.6940
# Epoch 126/150
# 768/768 [==============================] - 0s 34us/step - loss: 0.5926 - accuracy: 0.6875
# Epoch 127/150
# 768/768 [==============================] - 0s 40us/step - loss: 0.5947 - accuracy: 0.6901
# Epoch 128/150
# 768/768 [==============================] - 0s 29us/step - loss: 0.5929 - accuracy: 0.6914
# Epoch 129/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.6016 - accuracy: 0.6849
# Epoch 130/150
# 768/768 [==============================] - 0s 27us/step - loss: 0.6016 - accuracy: 0.6901
# Epoch 131/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.6162 - accuracy: 0.6888
# Epoch 132/150
# 768/768 [==============================] - 0s 31us/step - loss: 0.5951 - accuracy: 0.6940
# Epoch 133/150
# 768/768 [==============================] - 0s 43us/step - loss: 0.5901 - accuracy: 0.6901
# Epoch 134/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.5927 - accuracy: 0.6823
# Epoch 135/150
# 768/768 [==============================] - 0s 31us/step - loss: 0.5920 - accuracy: 0.6888
# Epoch 136/150
# 768/768 [==============================] - 0s 27us/step - loss: 0.5916 - accuracy: 0.6966
# Epoch 137/150
# 768/768 [==============================] - 0s 36us/step - loss: 0.5928 - accuracy: 0.6823
# Epoch 138/150
# 768/768 [==============================] - 0s 34us/step - loss: 0.5944 - accuracy: 0.6862
# Epoch 139/150
# 768/768 [==============================] - 0s 42us/step - loss: 0.5945 - accuracy: 0.6862
# Epoch 140/150
# 768/768 [==============================] - 0s 29us/step - loss: 0.6067 - accuracy: 0.6849
# Epoch 141/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.6068 - accuracy: 0.6888
# Epoch 142/150
# 768/768 [==============================] - 0s 27us/step - loss: 0.6015 - accuracy: 0.6836
# Epoch 143/150
# 768/768 [==============================] - 0s 30us/step - loss: 0.5929 - accuracy: 0.6927
# Epoch 144/150
# 768/768 [==============================] - 0s 34us/step - loss: 0.5899 - accuracy: 0.6914
# Epoch 145/150
# 768/768 [==============================] - 0s 40us/step - loss: 0.5928 - accuracy: 0.6940
# Epoch 146/150
# 768/768 [==============================] - 0s 35us/step - loss: 0.5922 - accuracy: 0.6914
# Epoch 147/150
# 768/768 [==============================] - 0s 35us/step - loss: 0.5913 - accuracy: 0.6901
# Epoch 148/150
# 768/768 [==============================] - 0s 38us/step - loss: 0.6027 - accuracy: 0.6823
# Epoch 149/150
# 768/768 [==============================] - 0s 32us/step - loss: 0.6027 - accuracy: 0.6875
# Epoch 150/150
# 768/768 [==============================] - 0s 44us/step - loss: 0.5945 - accuracy: 0.6862

# %% [markdown]
# # Evalúar el modelo
# Una ves entrenado el modelo utilizando el dataset completo, se debe evaluar el rendimiento de la red neuronal. Estos dara una idea de que tan bien modelamos nuestro dataset, pero no tendremos idea como se desempeñara el modelo con datos nuevos. En la realidad se debe de separar el dataset de training y el dataset de testing.
# Se puede evaluar el modelo en tu dataset de training utilizando la función evaluation() del modelo, pasándole la misma entrada y salida utilizada para el entrenamiento. Esto generará una predicción por cada registro, se podrán colectar scores, average loss y otras métricas como accuracy.

# %%
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 768/768 [==============================] - 0s 64us/step
# accuracy: 68.49%
