# %% [markdown]
# # Imports

# %%
import gymnasium as gym
import pygame
import random
import sys

# %% [markdown]
# # Entorno Jugable : ¡Pruébalo!

# %%
pygame.init()

# Configuración de pantalla de juego
width, height = 400, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("Entorno de Aprendizaje")

# Colores
white = (255, 255, 255)
black = (0, 0, 0)

# Jugador
player_size = 50
player_x = width // 2 - player_size // 2
player_y = height - 2 * player_size

# Obstáculos
obstacle_size = 50
obstacle_speed = 5
obstacle_frequency = 25  # A mayor valor, menos obstáculos
obstacles = []

# Reloj para controlar la velocidad del juego
clock = pygame.time.Clock()

# Función para mostrar un mensaje en la pantalla
def show_message(message, size, color, y_offset):
    font = pygame.font.Font(None, size)
    text = font.render(message, True, color)
    text_rect = text.get_rect(center=(width // 2, height // 2 + y_offset))
    screen.blit(text, text_rect)

# Bucle principal del juego
running = True
waiting_for_restart = False
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    keys = pygame.key.get_pressed()
    player_speed = 5
    player_x -= keys[pygame.K_LEFT] * player_speed
    player_x += keys[pygame.K_RIGHT] * player_speed

    # Límites del jugador
    player_x = max(0, min(player_x, width - player_size))

    # Generar obstáculos aleatorios
    if random.randint(0, obstacle_frequency) == 0:
        obstacle_x = random.randint(0, width - obstacle_size)
        obstacle_y = 0
        obstacles.append((obstacle_x, obstacle_y))

    # Mover y dibujar obstáculos
    new_obstacles = []
    for obstacle in obstacles:
        obstacle_x, obstacle_y = obstacle
        obstacle_y += obstacle_speed
        pygame.draw.rect(screen, white, (obstacle_x, obstacle_y, obstacle_size, obstacle_size))
        if obstacle_y < height:
            new_obstacles.append((obstacle_x, obstacle_y))
    obstacles = new_obstacles

    # Dibujar jugador
    pygame.draw.rect(screen, white, (player_x, player_y, player_size, player_size))

    # Verificar colisiones
    player_rect = pygame.Rect(player_x, player_y, player_size, player_size)
    for obstacle in obstacles:
        obstacle_rect = pygame.Rect(obstacle[0], obstacle[1], obstacle_size, obstacle_size)
        if player_rect.colliderect(obstacle_rect):
            show_message("Game Over", 36, white, -20)
            show_message("Press 'R' to Restart", 24, white, 20)
            pygame.display.flip()
            waiting_for_restart = True

    pygame.display.flip()
    screen.fill(black)
    clock.tick(30)

    # Bucle para esperar la pulsación de la tecla 'R' para reiniciar el juego
    while waiting_for_restart:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
                waiting_for_restart = False
            elif event.type == pygame.KEYDOWN:
                if event.key == pygame.K_r:
                    waiting_for_restart = False

        # Mensaje de reinicio en la pantalla
        show_message("Press 'R' to Restart", 24, white, 20)
        pygame.display.flip()
        clock.tick(30)

        # Limpiar y reiniciar el juego
        player_x = width // 2 - player_size // 2
        player_y = height - 2 * player_size
        obstacles = []

pygame.quit()
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# # Declaración de Entorno

# %%
pygame.init()

class SimpleGameEnv(gym.Env):
    def __init__(self):
        super(SimpleGameEnv, self).__init__()

        # Configuración de pantalla de juego
        self.width, self.height = 400, 600
        self.screen = pygame.display.set_mode((self.width, self.height))
        pygame.display.set_caption("Entorno de Aprendizaje")

        # Colores
        self.white = (255, 255, 255)
        self.black = (0, 0, 0)

        # Jugador
        self.player_size = 50
        self.player_x = self.width // 2 - self.player_size // 2
        self.player_y = self.height - 2 * self.player_size

        # Obstáculos
        self.obstacle_size = 50
        self.obstacle_speed = 5
        self.obstacle_frequency = 25  # A mayor valor, menos obstáculos
        self.obstacles = []

        # Reloj para controlar la velocidad del juego
        self.clock = pygame.time.Clock()

        # Definir el espacio de observación y de acción
        self.observation_space = gym.spaces.Discrete(2)  # Ajusta el espacio de observación según tu juego
        self.action_space = gym.spaces.Discrete(2)  # Ajusta el espacio de acción según tu juego

        # Define recompensas y penalizaciones
        self.reward_for_movement = 0.1
        self.reward_for_avoiding_obstacle = 1.0
        self.penalty_for_collision = -10

    def reset(self):
        # Reiniciar el juego y devolver el estado inicial
        self.player_x = self.width // 2 - self.player_size // 2
        self.player_y = self.height - 2 * self.player_size
        self.obstacles = []
        return self._get_observation()

    def step(self, action):
        # Realizar la acción en el juego y devolver la observación, la recompensa y si el episodio ha terminado
        self._handle_player_movement(action)
        self._generate_obstacles()
        self._move_and_draw_obstacles()
        self._draw_player()

        # Verificar colisiones
        collision = self._check_collisions()
        if collision:
            reward = self.penalty_for_collision
            done = True
        else:
            reward = self.reward_for_movement
            done = False

        pygame.display.flip()
        self.screen.fill(self.black)
        self.clock.tick(30)

        # Retorna información relevante para el agente Q-learning
        return self._get_observation(), reward, done, {}

    def render(self):
        # Mostrar el estado actual del juego
        pass

    def close(self):
        # Cerrar el entorno
        pygame.quit()
        sys.exit()

    def _get_observation(self):
        # Devuelve la observación actual
        return (self.player_x, self.player_y)

    def _handle_player_movement(self, action):
        # Manejar el movimiento del jugador según la acción
        player_speed = 5
        self.player_x += (2 * action - 1) * player_speed  # Mover a la izquierda si action es 0, mover a la derecha si action es 1
        self.player_x = max(0, min(self.player_x, self.width - self.player_size))


    def _generate_obstacles(self):
        # Generar obstáculos aleatorios
        if random.randint(0, self.obstacle_frequency) == 0:
            obstacle_x = random.randint(0, self.width - self.obstacle_size)
            obstacle_y = 0
            self.obstacles.append((obstacle_x, obstacle_y))

    def _move_and_draw_obstacles(self):
        # Mover y dibujar obstáculos
        new_obstacles = []
        for obstacle in self.obstacles:
            obstacle_x, obstacle_y = obstacle
            obstacle_y += self.obstacle_speed
            pygame.draw.rect(self.screen, self.white, (obstacle_x, obstacle_y, self.obstacle_size, self.obstacle_size))
            if obstacle_y < self.height:
                new_obstacles.append((obstacle_x, obstacle_y))
        self.obstacles = new_obstacles

    def _draw_player(self):
        # Dibujar jugador
        pygame.draw.rect(self.screen, self.white, (self.player_x, self.player_y, self.player_size, self.player_size))

    def _check_collisions(self):
        # Verificar colisiones entre el jugador y los obstáculos
        player_rect = pygame.Rect(self.player_x, self.player_y, self.player_size, self.player_size)
        for obstacle in self.obstacles:
            obstacle_rect = pygame.Rect(obstacle[0], obstacle[1], self.obstacle_size, self.obstacle_size)
            if player_rect.colliderect(obstacle_rect):
                return True  # Colisión detectada
        return False

# %% [markdown]
# ## Agente

# %%
class Agente:
    def __init__(self, alpha, gamma, epsilon):
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = {}

    def select_action(self, observation):
        if observation not in self.q_table or random.uniform(0, 1) < self.epsilon:
            action = random.choice([0, 1, 2])  # Exploración aleatoria
        else:
            action = max(self.q_table[observation], key=self.q_table[observation].get)  # Explotación basada en Q

        return action

    def update(self, observation, action, reward, next_observation, done):
        if observation not in self.q_table:
            self.q_table[observation] = {0: 0, 1: 0, 2: 0}

        if next_observation not in self.q_table:
            self.q_table[next_observation] = {0: 0, 1: 0, 2: 0}
            
        max_q_next = max(self.q_table[next_observation].values()) if not done else 0
        self.q_table[observation][action] += self.alpha * (reward + self.gamma * max_q_next - self.q_table[observation][action])

# %% [markdown]
# ## Bucle de Entrenamiento

# %%
import threading

def train_thread(env, agent, num_episodes):
    for episode in range(num_episodes):
        observation = env.reset()
        total_reward = 0

        while True:
            action = agent.select_action(observation)
            next_observation, reward, done, _ = env.step(action)
            total_reward += reward

            agent.update(observation, action, reward, next_observation, done)

            observation = next_observation

            if done:
                print(f"Hilo {threading.current_thread().name}, Episodio {episode + 1}, Recompensa total: {total_reward}")
                break

# %% [markdown]
# # ¡Ahora te toca a ti!

# %% [markdown]
# Puedes experimentar cambiando todos los parámetros, como el número de entrenamientos simultáneos, los hiperparámetros de entrenamiento (alpha, gamma, epsilon), probar con diferentes entornos, probar nuevos algoritmos...
#
# ¿Crees que puedes hacerlo mejor? ¡Seguro que sí!

# %%
pygame.init()

num_threads = 4
num_episodes_per_thread = 1000

threads = []
agents = [Agente(alpha=0.1, gamma=0.9, epsilon=0.1) for _ in range(num_threads)]

envs = [SimpleGameEnv() for _ in range(num_threads)]

for i in range(num_threads):
    thread = threading.Thread(target=train_thread, args=(envs[i], agents[i], num_episodes_per_thread), name=f"Thread-{i+1}")
    thread.start()
    threads.append(thread)

for thread in threads:
    thread.join()

for env in envs:
    env.close()
# Out:
# Hilo Thread-3, Episodio 1, Recompensa total: 10.700000000000024
# Hilo Thread-2, Episodio 1, Recompensa total: 12.200000000000045
# Hilo Thread-1, Episodio 1, Recompensa total: 17.800000000000125
# Hilo Thread-4, Episodio 1, Recompensa total: 20.30000000000016
# Hilo Thread-1, Episodio 2, Recompensa total: 2.1999999999999726
# Hilo Thread-2, Episodio 2, Recompensa total: 8.799999999999997
# Hilo Thread-3, Episodio 2, Recompensa total: 16.900000000000112
# Hilo Thread-4, Episodio 2, Recompensa total: 10.300000000000018
# Hilo Thread-1, Episodio 3, Recompensa total: 4.1999999999999655
# Hilo Thread-3, Episodio 3, Recompensa total: 0.19999999999997975
# Hilo Thread-2, Episodio 3, Recompensa total: 7.299999999999976
# Hilo Thread-3, Episodio 4, Recompensa total: -0.8000000000000167
# Hilo Thread-2, Episodio 4, Recompensa total: 3.5999999999999677
# Hilo Thread-4, Episodio 3, Recompensa total: 12.100000000000044
# Hilo Thread-3, Episodio 5, Recompensa total: 0.0999999999999801
# Hilo Thread-1, Episodio 4, Recompensa total: 16.0000000000001
# Hilo Thread-2, Episodio 5, Recompensa total: 4.4999999999999645
# Hilo Thread-1, Episodio 5, Recompensa total: 0.4999999999999787
# Hilo Thread-4, Episodio 4, Recompensa total: 18.300000000000132
# Hilo Thread-1, Episodio 6, Recompensa total: 10.600000000000023
# Hilo Thread-3, Episodio 6, Recompensa total: 24.000000000000213
# Hilo Thread-2, Episodio 6, Recompensa total: 16.200000000000102
# Hilo Thread-4, Episodio 5, Recompensa total: 9.500000000000007
# Hilo Thread-1, Episodio 7, Recompensa total: 5.399999999999961
# Hilo Thread-2, Episodio 7, Recompensa total: 4.299999999999965
# Hilo Thread-3, Episodio 7, Recompensa total: 14.500000000000078
# Hilo Thread-4, Episodio 6, Recompensa total: 7.59999999999998
# Hilo Thread-1, Episodio 8, Recompensa total: 7.899999999999984
# Hilo Thread-4, Episodio 7, Recompensa total: 5.69999999999996
# Hilo Thread-1, Episodio 9, Recompensa total: -0.10000000000001918
# Hilo Thread-2, Episodio 8, Recompensa total: 20.100000000000158
# Hilo Thread-3, Episodio 8, Recompensa total: 13.300000000000061
# Hilo Thread-4, Episodio 8, Recompensa total: -0.6000000000000174
# Hilo Thread-1, Episodio 10, Recompensa total: 1.2999999999999758
# Hilo Thread-3, Episodio 9, Recompensa total: 0.7999999999999776
# Hilo Thread-2, Episodio 9, Recompensa total: 3.3999999999999684
# Hilo Thread-3, Episodio 10, Recompensa total: -1.000000000000016
# Hilo Thread-1, Episodio 11, Recompensa total: 6.599999999999966
# Hilo Thread-2, Episodio 10, Recompensa total: 7.999999999999986
# Hilo Thread-3, Episodio 11, Recompensa total: 2.4999999999999716
# Hilo Thread-1, Episodio 12, Recompensa total: 2.89999999999997
# Hilo Thread-4, Episodio 9, Recompensa total: 24.40000000000022
# Hilo Thread-2, Episodio 11, Recompensa total: -0.9000000000000163
# Hilo Thread-2, Episodio 12, Recompensa total: -1.000000000000016
# Hilo Thread-4, Episodio 10, Recompensa total: 0.19999999999997975
# Hilo Thread-3, Episodio 12, Recompensa total: 10.300000000000018
# Hilo Thread-2, Episodio 13, Recompensa total: -0.6000000000000174
# Hilo Thread-1, Episodio 13, Recompensa total: 13.400000000000063
# Hilo Thread-2, Episodio 14, Recompensa total: 1.1999999999999762
# Hilo Thread-4, Episodio 11, Recompensa total: 10.500000000000021
# Hilo Thread-1, Episodio 14, Recompensa total: 3.199999999999969
# Hilo Thread-3, Episodio 13, Recompensa total: 16.1000000000001
# Hilo Thread-2, Episodio 15, Recompensa total: 2.99999999999997
# Hilo Thread-1, Episodio 15, Recompensa total: 3.9999999999999662
# Hilo Thread-3, Episodio 14, Recompensa total: 2.399999999999972
# Hilo Thread-2, Episodio 16, Recompensa total: 0.7999999999999776
# Hilo Thread-4, Episodio 12, Recompensa total: 17.100000000000115
# Hilo Thread-3, Episodio 15, Recompensa total: 1.0999999999999766
# Hilo Thread-2, Episodio 17, Recompensa total: 0.8999999999999773
# Hilo Thread-1, Episodio 16, Recompensa total: 9.900000000000013
# Hilo Thread-3, Episodio 16, Recompensa total: 2.399999999999972
# Hilo Thread-2, Episodio 18, Recompensa total: 3.3999999999999684
# Hilo Thread-4, Episodio 13, Recompensa total: 11.000000000000028
# Hilo Thread-1, Episodio 17, Recompensa total: 0.9999999999999769
# Hilo Thread-2, Episodio 19, Recompensa total: -1.9539925233402755e-14
# Hilo Thread-3, Episodio 17, Recompensa total: 8.099999999999987
# Hilo Thread-4, Episodio 14, Recompensa total: 11.900000000000041
# Hilo Thread-3, Episodio 18, Recompensa total: 0.0999999999999801
# Hilo Thread-1, Episodio 18, Recompensa total: 24.50000000000022
# Hilo Thread-3, Episodio 19, Recompensa total: 1.6999999999999744
# Hilo Thread-4, Episodio 15, Recompensa total: 7.099999999999973
# Hilo Thread-2, Episodio 20, Recompensa total: 19.300000000000146
# Hilo Thread-3, Episodio 20, Recompensa total: 2.4999999999999716
# Hilo Thread-2, Episodio 21, Recompensa total: 3.499999999999968
# Hilo Thread-1, Episodio 19, Recompensa total: 7.399999999999977
# Hilo Thread-3, Episodio 21, Recompensa total: 0.699999999999978
# Hilo Thread-1, Episodio 20, Recompensa total: 0.4999999999999787
# Hilo Thread-2, Episodio 22, Recompensa total: 2.5999999999999712
# Hilo Thread-4, Episodio 16, Recompensa total: 18.000000000000128
# Hilo Thread-3, Episodio 22, Recompensa total: -0.10000000000001918
# Hilo Thread-3, Episodio 23, Recompensa total: -0.6000000000000174
# Hilo Thread-4, Episodio 17, Recompensa total: 4.1999999999999655
# Hilo Thread-1, Episodio 21, Recompensa total: 10.000000000000014
# Hilo Thread-1, Episodio 22, Recompensa total: -1.000000000000016
# Hilo Thread-2, Episodio 23, Recompensa total: 17.800000000000125
# Hilo Thread-3, Episodio 24, Recompensa total: 5.099999999999962
# Hilo Thread-4, Episodio 18, Recompensa total: 11.10000000000003
# Hilo Thread-3, Episodio 25, Recompensa total: 0.4999999999999787
# Hilo Thread-2, Episodio 24, Recompensa total: 3.199999999999969
# Hilo Thread-4, Episodio 19, Recompensa total: -0.5000000000000178
# Hilo Thread-1, Episodio 23, Recompensa total: 9.400000000000006
# Hilo Thread-3, Episodio 26, Recompensa total: 8.499999999999993
# Hilo Thread-4, Episodio 20, Recompensa total: 4.999999999999963
# Hilo Thread-1, Episodio 24, Recompensa total: 7.399999999999977
# Hilo Thread-2, Episodio 25, Recompensa total: 18.300000000000132
# Hilo Thread-4, Episodio 21, Recompensa total: 9.300000000000004
# Hilo Thread-1, Episodio 25, Recompensa total: 9.0
# Hilo Thread-3, Episodio 27, Recompensa total: 15.000000000000085
# Hilo Thread-3, Episodio 28, Recompensa total: 0.8999999999999773
# Hilo Thread-4, Episodio 22, Recompensa total: 6.999999999999972
# Hilo Thread-1, Episodio 26, Recompensa total: 7.899999999999984
# Hilo Thread-2, Episodio 26, Recompensa total: 26.400000000000247
# Hilo Thread-3, Episodio 29, Recompensa total: 4.999999999999963
# Hilo Thread-1, Episodio 27, Recompensa total: -0.9000000000000163
# Hilo Thread-4, Episodio 23, Recompensa total: 4.599999999999964
# Hilo Thread-2, Episodio 27, Recompensa total: 0.19999999999997975
# Hilo Thread-3, Episodio 30, Recompensa total: 0.19999999999997975
# Hilo Thread-4, Episodio 24, Recompensa total: 3.199999999999969
# Hilo Thread-3, Episodio 31, Recompensa total: 0.8999999999999773
# Hilo Thread-1, Episodio 28, Recompensa total: 13.100000000000058
# Hilo Thread-2, Episodio 28, Recompensa total: 12.600000000000051
# Hilo Thread-4, Episodio 25, Recompensa total: 8.099999999999987
# Hilo Thread-3, Episodio 32, Recompensa total: 5.499999999999961
# Hilo Thread-1, Episodio 29, Recompensa total: 9.100000000000001
# Hilo Thread-4, Episodio 26, Recompensa total: -0.20000000000001883
# Hilo Thread-2, Episodio 29, Recompensa total: 6.399999999999963
# Hilo Thread-2, Episodio 30, Recompensa total: 0.7999999999999776
# Hilo Thread-3, Episodio 33, Recompensa total: 9.0
# Hilo Thread-1, Episodio 30, Recompensa total: 5.8999999999999595
# Hilo Thread-4, Episodio 27, Recompensa total: 7.6999999999999815
# Hilo Thread-3, Episodio 34, Recompensa total: 0.8999999999999773
# Hilo Thread-2, Episodio 31, Recompensa total: 11.600000000000037
# Hilo Thread-3, Episodio 35, Recompensa total: 1.3999999999999755
# Hilo Thread-4, Episodio 28, Recompensa total: 8.099999999999987
# Hilo Thread-1, Episodio 31, Recompensa total: 14.60000000000008
# Hilo Thread-2, Episodio 32, Recompensa total: 4.799999999999963
# Hilo Thread-4, Episodio 29, Recompensa total: 4.899999999999963
# Hilo Thread-3, Episodio 36, Recompensa total: 5.8999999999999595
# Hilo Thread-2, Episodio 33, Recompensa total: 1.9999999999999734
# Hilo Thread-1, Episodio 32, Recompensa total: 13.500000000000064
# Hilo Thread-3, Episodio 37, Recompensa total: 2.1999999999999726
# Hilo Thread-4, Episodio 30, Recompensa total: 3.6999999999999673
# Hilo Thread-2, Episodio 34, Recompensa total: -0.4000000000000181
# Hilo Thread-4, Episodio 31, Recompensa total: 1.0999999999999766
# Hilo Thread-2, Episodio 35, Recompensa total: 1.3999999999999755
# Hilo Thread-1, Episodio 33, Recompensa total: 10.900000000000027
# Hilo Thread-4, Episodio 32, Recompensa total: 1.4999999999999751
# Hilo Thread-2, Episodio 36, Recompensa total: -1.9539925233402755e-14
# Hilo Thread-1, Episodio 34, Recompensa total: 0.2999999999999794
# Hilo Thread-4, Episodio 33, Recompensa total: 2.99999999999997
# Hilo Thread-2, Episodio 37, Recompensa total: 1.5999999999999748
# Hilo Thread-1, Episodio 35, Recompensa total: 1.1999999999999762
# Hilo Thread-4, Episodio 34, Recompensa total: 0.5999999999999783
# Hilo Thread-3, Episodio 38, Recompensa total: 40.00000000000044
# Hilo Thread-2, Episodio 38, Recompensa total: 3.2999999999999687
# Hilo Thread-4, Episodio 35, Recompensa total: 0.4999999999999787
# Hilo Thread-3, Episodio 39, Recompensa total: 3.3999999999999684
# Hilo Thread-1, Episodio 36, Recompensa total: 11.400000000000034
# Hilo Thread-4, Episodio 36, Recompensa total: 3.2999999999999687
# Hilo Thread-1, Episodio 37, Recompensa total: 0.8999999999999773
# Hilo Thread-3, Episodio 40, Recompensa total: 9.70000000000001
# Hilo Thread-2, Episodio 39, Recompensa total: 19.700000000000152
# Hilo Thread-4, Episodio 37, Recompensa total: 5.8999999999999595
# Hilo Thread-2, Episodio 40, Recompensa total: 0.0999999999999801
# Hilo Thread-1, Episodio 38, Recompensa total: 11.300000000000033
# Hilo Thread-3, Episodio 41, Recompensa total: 6.599999999999966
# Hilo Thread-4, Episodio 38, Recompensa total: 4.999999999999963
# Hilo Thread-2, Episodio 41, Recompensa total: 0.699999999999978
# Hilo Thread-4, Episodio 39, Recompensa total: 0.2999999999999794
# Hilo Thread-3, Episodio 42, Recompensa total: 3.8999999999999666
# Hilo Thread-2, Episodio 42, Recompensa total: 6.399999999999963
# Hilo Thread-4, Episodio 40, Recompensa total: 2.699999999999971
# Hilo Thread-2, Episodio 43, Recompensa total: 1.8999999999999737
# Hilo Thread-1, Episodio 39, Recompensa total: 26.800000000000253
# Hilo Thread-3, Episodio 43, Recompensa total: 11.700000000000038
# Hilo Thread-4, Episodio 41, Recompensa total: 0.2999999999999794
# Hilo Thread-1, Episodio 40, Recompensa total: 0.19999999999997975
# Hilo Thread-2, Episodio 44, Recompensa total: 1.2999999999999758
# Hilo Thread-4, Episodio 42, Recompensa total: 1.0999999999999766
# Hilo Thread-1, Episodio 41, Recompensa total: -0.8000000000000167
# Hilo Thread-3, Episodio 44, Recompensa total: 11.10000000000003
# Hilo Thread-2, Episodio 45, Recompensa total: 4.699999999999964
# Hilo Thread-4, Episodio 43, Recompensa total: 2.399999999999972
# Hilo Thread-1, Episodio 42, Recompensa total: 2.1999999999999726
# Hilo Thread-2, Episodio 46, Recompensa total: 3.3999999999999684
# Hilo Thread-3, Episodio 45, Recompensa total: 12.900000000000055
# Hilo Thread-4, Episodio 44, Recompensa total: 15.200000000000088
# Hilo Thread-1, Episodio 43, Recompensa total: 14.500000000000078
# Hilo Thread-3, Episodio 46, Recompensa total: 8.399999999999991
# Hilo Thread-1, Episodio 44, Recompensa total: 1.8999999999999737
# Hilo Thread-4, Episodio 45, Recompensa total: 9.100000000000001
# Hilo Thread-3, Episodio 47, Recompensa total: 0.7999999999999776
# Hilo Thread-2, Episodio 47, Recompensa total: 27.40000000000026
# Hilo Thread-1, Episodio 45, Recompensa total: 3.199999999999969
# Hilo Thread-3, Episodio 48, Recompensa total: 0.19999999999997975
# Hilo Thread-4, Episodio 46, Recompensa total: 7.399999999999977
# Hilo Thread-2, Episodio 48, Recompensa total: 2.89999999999997
# Hilo Thread-1, Episodio 46, Recompensa total: 2.399999999999972
# Hilo Thread-4, Episodio 47, Recompensa total: 0.5999999999999783
# Hilo Thread-2, Episodio 49, Recompensa total: 0.7999999999999776
# Hilo Thread-3, Episodio 49, Recompensa total: 4.699999999999964
# Hilo Thread-1, Episodio 47, Recompensa total: 1.3999999999999755
# Hilo Thread-2, Episodio 50, Recompensa total: -0.6000000000000174
# Hilo Thread-3, Episodio 50, Recompensa total: 7.59999999999998
# Hilo Thread-2, Episodio 51, Recompensa total: -0.5000000000000178
# Hilo Thread-4, Episodio 48, Recompensa total: 21.70000000000018
# Hilo Thread-1, Episodio 48, Recompensa total: 17.100000000000115
# Hilo Thread-2, Episodio 52, Recompensa total: 2.89999999999997
# Hilo Thread-3, Episodio 51, Recompensa total: 7.999999999999986
# Hilo Thread-4, Episodio 49, Recompensa total: 3.9999999999999662
# Hilo Thread-2, Episodio 53, Recompensa total: 2.7999999999999705
# Hilo Thread-1, Episodio 49, Recompensa total: 10.300000000000018
# Hilo Thread-3, Episodio 52, Recompensa total: 11.400000000000034
# Hilo Thread-4, Episodio 50, Recompensa total: 6.19999999999996
# Hilo Thread-2, Episodio 54, Recompensa total: 7.6999999999999815
# Hilo Thread-1, Episodio 50, Recompensa total: 6.399999999999963
# Hilo Thread-4, Episodio 51, Recompensa total: -0.4000000000000181
# Hilo Thread-2, Episodio 55, Recompensa total: 0.2999999999999794
# Hilo Thread-4, Episodio 52, Recompensa total: 2.399999999999972
# Hilo Thread-2, Episodio 56, Recompensa total: 1.4999999999999751
# Hilo Thread-4, Episodio 53, Recompensa total: 2.2999999999999723
# Hilo Thread-2, Episodio 57, Recompensa total: 11.80000000000004
# Hilo Thread-1, Episodio 51, Recompensa total: 43.60000000000049
# Hilo Thread-4, Episodio 54, Recompensa total: 17.600000000000122
# Hilo Thread-3, Episodio 53, Recompensa total: 65.39999999999999
# Hilo Thread-4, Episodio 55, Recompensa total: 6.799999999999969
# Hilo Thread-1, Episodio 52, Recompensa total: 10.300000000000018
# Hilo Thread-3, Episodio 54, Recompensa total: 5.399999999999961
# Hilo Thread-4, Episodio 56, Recompensa total: 4.999999999999963
# Hilo Thread-3, Episodio 55, Recompensa total: -0.3000000000000185
# Hilo Thread-1, Episodio 53, Recompensa total: 9.600000000000009
# Hilo Thread-4, Episodio 57, Recompensa total: 2.5999999999999712
# Hilo Thread-1, Episodio 54, Recompensa total: 2.7999999999999705
# Hilo Thread-3, Episodio 56, Recompensa total: 9.70000000000001
# Hilo Thread-4, Episodio 58, Recompensa total: 1.1999999999999762
# Hilo Thread-1, Episodio 55, Recompensa total: 2.699999999999971
# Hilo Thread-2, Episodio 58, Recompensa total: 73.19999999999955
# Hilo Thread-3, Episodio 57, Recompensa total: 10.600000000000023
# Hilo Thread-2, Episodio 59, Recompensa total: -0.6000000000000174
# Hilo Thread-2, Episodio 60, Recompensa total: 0.0999999999999801
# Hilo Thread-1, Episodio 56, Recompensa total: 16.500000000000107
# Hilo Thread-4, Episodio 59, Recompensa total: 30.300000000000303
# Hilo Thread-2, Episodio 61, Recompensa total: 5.599999999999961
# Hilo Thread-1, Episodio 57, Recompensa total: 4.4999999999999645
# Hilo Thread-2, Episodio 62, Recompensa total: -1.9539925233402755e-14
# Hilo Thread-3, Episodio 58, Recompensa total: 35.300000000000374
# Hilo Thread-3, Episodio 59, Recompensa total: 1.799999999999974
# Hilo Thread-2, Episodio 63, Recompensa total: 14.400000000000077
# Hilo Thread-3, Episodio 60, Recompensa total: 1.9999999999999734
# Hilo Thread-4, Episodio 60, Recompensa total: 50.900000000000595
# Hilo Thread-2, Episodio 64, Recompensa total: 15.700000000000095
# Hilo Thread-3, Episodio 61, Recompensa total: 12.700000000000053
# Hilo Thread-1, Episodio 58, Recompensa total: 53.80000000000064
# Hilo Thread-3, Episodio 62, Recompensa total: 1.4999999999999751
# Hilo Thread-4, Episodio 61, Recompensa total: 14.800000000000082
# Hilo Thread-2, Episodio 65, Recompensa total: 14.900000000000084
# Hilo Thread-4, Episodio 62, Recompensa total: -0.4000000000000181
# Hilo Thread-4, Episodio 63, Recompensa total: 0.0999999999999801
# Hilo Thread-3, Episodio 63, Recompensa total: 13.300000000000061
# Hilo Thread-4, Episodio 64, Recompensa total: 7.999999999999986
# Hilo Thread-3, Episodio 64, Recompensa total: 7.799999999999983
# Hilo Thread-3, Episodio 65, Recompensa total: 8.099999999999987
# Hilo Thread-2, Episodio 66, Recompensa total: 42.400000000000475
# Hilo Thread-3, Episodio 66, Recompensa total: 0.7999999999999776
# Hilo Thread-2, Episodio 67, Recompensa total: 6.399999999999963
# Hilo Thread-3, Episodio 67, Recompensa total: 5.599999999999961
# Hilo Thread-1, Episodio 59, Recompensa total: 85.79999999999883
# Hilo Thread-2, Episodio 68, Recompensa total: 4.4999999999999645
# Hilo Thread-3, Episodio 68, Recompensa total: 0.5999999999999783
# Hilo Thread-4, Episodio 65, Recompensa total: 53.10000000000063
# Hilo Thread-3, Episodio 69, Recompensa total: 4.399999999999965
# Hilo Thread-1, Episodio 60, Recompensa total: 20.700000000000166
# Hilo Thread-3, Episodio 70, Recompensa total: 7.399999999999977
# Hilo Thread-1, Episodio 61, Recompensa total: 7.799999999999983
# Hilo Thread-4, Episodio 66, Recompensa total: 23.600000000000207
# Hilo Thread-2, Episodio 69, Recompensa total: 38.200000000000415
# Hilo Thread-4, Episodio 67, Recompensa total: 2.4999999999999716
# Hilo Thread-3, Episodio 71, Recompensa total: 13.20000000000006
# Hilo Thread-2, Episodio 70, Recompensa total: 2.099999999999973
# Hilo Thread-4, Episodio 68, Recompensa total: 1.4999999999999751
# Hilo Thread-3, Episodio 72, Recompensa total: 7.299999999999976
# Hilo Thread-1, Episodio 62, Recompensa total: 28.300000000000274
# Hilo Thread-2, Episodio 71, Recompensa total: 14.200000000000074
# Hilo Thread-4, Episodio 69, Recompensa total: 6.299999999999962
# Hilo Thread-3, Episodio 73, Recompensa total: -1.9539925233402755e-14
# Hilo Thread-1, Episodio 63, Recompensa total: 7.299999999999976
# Hilo Thread-4, Episodio 70, Recompensa total: 6.599999999999966
# Hilo Thread-2, Episodio 72, Recompensa total: 8.699999999999996
# Hilo Thread-3, Episodio 74, Recompensa total: 14.100000000000072
# Hilo Thread-2, Episodio 73, Recompensa total: 1.5999999999999748
# Hilo Thread-4, Episodio 71, Recompensa total: 8.099999999999987
# Hilo Thread-3, Episodio 75, Recompensa total: -0.3000000000000185
# Hilo Thread-1, Episodio 64, Recompensa total: 18.700000000000138
# Hilo Thread-4, Episodio 72, Recompensa total: 3.199999999999969
# Hilo Thread-1, Episodio 65, Recompensa total: 4.4999999999999645
# Hilo Thread-2, Episodio 74, Recompensa total: 20.100000000000158
# Hilo Thread-1, Episodio 66, Recompensa total: -0.6000000000000174
# Hilo Thread-3, Episodio 76, Recompensa total: 25.80000000000024
# Hilo Thread-2, Episodio 75, Recompensa total: 12.900000000000055
# Hilo Thread-3, Episodio 77, Recompensa total: 7.199999999999974
# Hilo Thread-3, Episodio 78, Recompensa total: -0.4000000000000181
# Hilo Thread-4, Episodio 73, Recompensa total: 40.70000000000045
# Hilo Thread-1, Episodio 67, Recompensa total: 25.20000000000023
# Hilo Thread-3, Episodio 79, Recompensa total: -1.9539925233402755e-14
# Hilo Thread-1, Episodio 68, Recompensa total: 0.4999999999999787
# Hilo Thread-3, Episodio 80, Recompensa total: 0.7999999999999776
# Hilo Thread-2, Episodio 76, Recompensa total: 29.600000000000293
# Hilo Thread-4, Episodio 74, Recompensa total: 14.700000000000081
# Hilo Thread-3, Episodio 81, Recompensa total: 4.699999999999964
# Hilo Thread-2, Episodio 77, Recompensa total: 5.69999999999996
# Hilo Thread-4, Episodio 75, Recompensa total: 7.199999999999974
# Hilo Thread-1, Episodio 69, Recompensa total: 19.60000000000015
# Hilo Thread-1, Episodio 70, Recompensa total: -1.9539925233402755e-14
# Hilo Thread-3, Episodio 82, Recompensa total: 10.500000000000021
# Hilo Thread-4, Episodio 76, Recompensa total: 10.700000000000024
# Hilo Thread-2, Episodio 78, Recompensa total: 17.700000000000124
# Hilo Thread-3, Episodio 83, Recompensa total: 6.19999999999996
# Hilo Thread-2, Episodio 79, Recompensa total: 6.299999999999962
# Hilo Thread-3, Episodio 84, Recompensa total: 3.799999999999967
# Hilo Thread-4, Episodio 77, Recompensa total: 13.300000000000061
# Hilo Thread-1, Episodio 71, Recompensa total: 32.30000000000033
# Hilo Thread-4, Episodio 78, Recompensa total: -0.8000000000000167
# Hilo Thread-3, Episodio 85, Recompensa total: 0.19999999999997975
# Hilo Thread-4, Episodio 79, Recompensa total: 0.2999999999999794
# Hilo Thread-3, Episodio 86, Recompensa total: 2.5999999999999712
# Hilo Thread-2, Episodio 80, Recompensa total: 17.200000000000117
# Hilo Thread-3, Episodio 87, Recompensa total: 3.199999999999969
# Hilo Thread-2, Episodio 81, Recompensa total: 7.399999999999977
# Hilo Thread-1, Episodio 72, Recompensa total: 23.500000000000206
# Hilo Thread-3, Episodio 88, Recompensa total: 6.19999999999996
# Hilo Thread-1, Episodio 73, Recompensa total: 3.499999999999968
# Hilo Thread-2, Episodio 82, Recompensa total: 8.899999999999999
# Hilo Thread-3, Episodio 89, Recompensa total: 2.699999999999971
# Hilo Thread-1, Episodio 74, Recompensa total: -0.20000000000001883
# Hilo Thread-4, Episodio 80, Recompensa total: 45.00000000000051
# Hilo Thread-1, Episodio 75, Recompensa total: -0.9000000000000163
# Hilo Thread-2, Episodio 83, Recompensa total: 11.900000000000041
# Hilo Thread-4, Episodio 81, Recompensa total: 1.4999999999999751
# Hilo Thread-2, Episodio 84, Recompensa total: 3.799999999999967
# Hilo Thread-3, Episodio 90, Recompensa total: 34.40000000000036
# Hilo Thread-2, Episodio 85, Recompensa total: 3.5999999999999677
# Hilo Thread-1, Episodio 76, Recompensa total: 33.00000000000034
# Hilo Thread-1, Episodio 77, Recompensa total: 7.6999999999999815
# Hilo Thread-3, Episodio 91, Recompensa total: 17.800000000000125
# Hilo Thread-4, Episodio 82, Recompensa total: 42.10000000000047
# Hilo Thread-2, Episodio 86, Recompensa total: 21.200000000000173
# Hilo Thread-2, Episodio 87, Recompensa total: 1.1999999999999762
# Hilo Thread-2, Episodio 88, Recompensa total: 4.799999999999963
# Hilo Thread-3, Episodio 92, Recompensa total: 22.40000000000019
# Hilo Thread-4, Episodio 83, Recompensa total: 22.700000000000195
# Hilo Thread-1, Episodio 78, Recompensa total: 29.600000000000293
# Hilo Thread-1, Episodio 79, Recompensa total: 3.499999999999968
# Hilo Thread-2, Episodio 89, Recompensa total: 13.90000000000007
# Hilo Thread-4, Episodio 84, Recompensa total: 16.600000000000108
# Hilo Thread-2, Episodio 90, Recompensa total: -1.9539925233402755e-14
# Hilo Thread-4, Episodio 85, Recompensa total: -1.000000000000016
# Hilo Thread-3, Episodio 93, Recompensa total: 29.800000000000296
# Hilo Thread-1, Episodio 80, Recompensa total: 24.60000000000022
# Hilo Thread-3, Episodio 94, Recompensa total: 7.299999999999976
# Hilo Thread-3, Episodio 95, Recompensa total: 4.399999999999965
# Hilo Thread-2, Episodio 91, Recompensa total: 29.30000000000029
# Hilo Thread-1, Episodio 81, Recompensa total: 7.899999999999984
# Hilo Thread-4, Episodio 86, Recompensa total: 39.600000000000435
# Hilo Thread-2, Episodio 92, Recompensa total: 11.10000000000003
# Hilo Thread-3, Episodio 96, Recompensa total: 13.400000000000063
# Hilo Thread-1, Episodio 82, Recompensa total: 22.500000000000192
# Hilo Thread-1, Episodio 83, Recompensa total: 0.19999999999997975
# Hilo Thread-2, Episodio 93, Recompensa total: 31.000000000000313
# Hilo Thread-3, Episodio 97, Recompensa total: 42.80000000000048
# Hilo Thread-2, Episodio 94, Recompensa total: 15.800000000000097
# Hilo Thread-1, Episodio 84, Recompensa total: 42.500000000000476
# Hilo Thread-3, Episodio 98, Recompensa total: 13.700000000000067
# Hilo Thread-2, Episodio 95, Recompensa total: 5.999999999999959
# Hilo Thread-2, Episodio 96, Recompensa total: 0.699999999999978
# Hilo Thread-1, Episodio 85, Recompensa total: 10.600000000000023
# Hilo Thread-4, Episodio 87, Recompensa total: 98.49999999999811
# Hilo Thread-1, Episodio 86, Recompensa total: -0.4000000000000181
# Hilo Thread-2, Episodio 97, Recompensa total: 5.499999999999961
# Hilo Thread-4, Episodio 88, Recompensa total: 8.799999999999997
# Hilo Thread-3, Episodio 99, Recompensa total: 34.50000000000036
# Hilo Thread-1, Episodio 87, Recompensa total: 16.0000000000001
# Hilo Thread-2, Episodio 98, Recompensa total: 15.500000000000092
# Hilo Thread-4, Episodio 89, Recompensa total: 3.6999999999999673
# Hilo Thread-1, Episodio 88, Recompensa total: 3.5999999999999677
# Hilo Thread-3, Episodio 100, Recompensa total: 12.400000000000048
# Hilo Thread-2, Episodio 99, Recompensa total: 3.3999999999999684
# Hilo Thread-4, Episodio 90, Recompensa total: 7.799999999999983
# Hilo Thread-1, Episodio 89, Recompensa total: 1.2999999999999758
# Hilo Thread-2, Episodio 100, Recompensa total: -1.000000000000016
# Hilo Thread-4, Episodio 91, Recompensa total: 3.799999999999967
# Hilo Thread-1, Episodio 90, Recompensa total: 2.099999999999973
# Hilo Thread-2, Episodio 101, Recompensa total: 1.3999999999999755
# Hilo Thread-2, Episodio 102, Recompensa total: 1.6999999999999744
# Hilo Thread-1, Episodio 91, Recompensa total: 4.799999999999963
# Hilo Thread-3, Episodio 101, Recompensa total: 29.800000000000296
# Hilo Thread-2, Episodio 103, Recompensa total: -0.3000000000000185
# Hilo Thread-4, Episodio 92, Recompensa total: 14.200000000000074
# Hilo Thread-3, Episodio 102, Recompensa total: 5.099999999999962
# Hilo Thread-4, Episodio 93, Recompensa total: 2.399999999999972
# Hilo Thread-3, Episodio 103, Recompensa total: -0.4000000000000181
# Hilo Thread-4, Episodio 94, Recompensa total: 4.299999999999965
# Hilo Thread-3, Episodio 104, Recompensa total: 4.299999999999965
# Hilo Thread-3, Episodio 105, Recompensa total: -0.4000000000000181
# Hilo Thread-2, Episodio 104, Recompensa total: 39.600000000000435
# Hilo Thread-4, Episodio 95, Recompensa total: 12.000000000000043
# Hilo Thread-1, Episodio 92, Recompensa total: 54.600000000000605
# Hilo Thread-3, Episodio 106, Recompensa total: 3.6999999999999673
# Hilo Thread-2, Episodio 105, Recompensa total: 4.1999999999999655
# Hilo Thread-4, Episodio 96, Recompensa total: 5.399999999999961
# Hilo Thread-3, Episodio 107, Recompensa total: 16.1000000000001
# Hilo Thread-2, Episodio 106, Recompensa total: 12.600000000000051
# Hilo Thread-1, Episodio 93, Recompensa total: 24.900000000000226
# Hilo Thread-4, Episodio 97, Recompensa total: 23.70000000000021
# Hilo Thread-2, Episodio 107, Recompensa total: 2.4999999999999716
# Hilo Thread-4, Episodio 98, Recompensa total: 7.59999999999998
# Hilo Thread-2, Episodio 108, Recompensa total: 18.90000000000014
# Hilo Thread-3, Episodio 108, Recompensa total: 50.00000000000058
# Hilo Thread-3, Episodio 109, Recompensa total: -0.9000000000000163
# Hilo Thread-1, Episodio 94, Recompensa total: 56.700000000000486
# Hilo Thread-4, Episodio 99, Recompensa total: 34.000000000000355
# Hilo Thread-2, Episodio 109, Recompensa total: 30.300000000000303
# Hilo Thread-4, Episodio 100, Recompensa total: -0.10000000000001918
# Hilo Thread-3, Episodio 110, Recompensa total: 13.90000000000007
# Hilo Thread-1, Episodio 95, Recompensa total: 14.800000000000082
# Hilo Thread-4, Episodio 101, Recompensa total: 3.799999999999967
# Hilo Thread-2, Episodio 110, Recompensa total: 9.400000000000006
# Hilo Thread-3, Episodio 111, Recompensa total: 3.8999999999999666
# Hilo Thread-1, Episodio 96, Recompensa total: 2.99999999999997
# Hilo Thread-2, Episodio 111, Recompensa total: 8.699999999999996
# Hilo Thread-2, Episodio 112, Recompensa total: 4.999999999999963
# Hilo Thread-1, Episodio 97, Recompensa total: 29.200000000000287
# Hilo Thread-4, Episodio 102, Recompensa total: 60.10000000000029
# Hilo Thread-2, Episodio 113, Recompensa total: 33.300000000000345
# Hilo Thread-4, Episodio 103, Recompensa total: 0.8999999999999773
# Hilo Thread-3, Episodio 112, Recompensa total: 68.49999999999982
# Hilo Thread-2, Episodio 114, Recompensa total: 0.699999999999978
# Hilo Thread-4, Episodio 104, Recompensa total: 4.099999999999966
# Hilo Thread-1, Episodio 98, Recompensa total: 40.60000000000045
# Hilo Thread-1, Episodio 99, Recompensa total: -0.9000000000000163
# Hilo Thread-4, Episodio 105, Recompensa total: 18.10000000000013
# Hilo Thread-1, Episodio 100, Recompensa total: 5.099999999999962
# Hilo Thread-3, Episodio 113, Recompensa total: 32.40000000000033
# Hilo Thread-2, Episodio 115, Recompensa total: 27.30000000000026
# Hilo Thread-1, Episodio 101, Recompensa total: 3.2999999999999687
# Hilo Thread-2, Episodio 116, Recompensa total: 1.8999999999999737
# Hilo Thread-1, Episodio 102, Recompensa total: -0.10000000000001918
# Hilo Thread-4, Episodio 106, Recompensa total: 17.40000000000012
# Hilo Thread-3, Episodio 114, Recompensa total: 16.0000000000001
# Hilo Thread-4, Episodio 107, Recompensa total: 3.799999999999967
# Hilo Thread-2, Episodio 117, Recompensa total: 15.700000000000095
# Hilo Thread-4, Episodio 108, Recompensa total: 7.299999999999976
# Hilo Thread-3, Episodio 115, Recompensa total: 20.20000000000016
# Hilo Thread-2, Episodio 118, Recompensa total: 9.70000000000001
# Hilo Thread-2, Episodio 119, Recompensa total: 4.099999999999966
# Hilo Thread-3, Episodio 116, Recompensa total: 9.70000000000001
# Hilo Thread-4, Episodio 109, Recompensa total: 15.000000000000085
# Hilo Thread-2, Episodio 120, Recompensa total: -0.4000000000000181
# Hilo Thread-3, Episodio 117, Recompensa total: 7.799999999999983
# Hilo Thread-2, Episodio 121, Recompensa total: 8.399999999999991
# Hilo Thread-1, Episodio 103, Recompensa total: 74.29999999999949
# Hilo Thread-3, Episodio 118, Recompensa total: 3.2999999999999687
# Hilo Thread-3, Episodio 119, Recompensa total: 6.19999999999996
# Hilo Thread-1, Episodio 104, Recompensa total: 8.699999999999996
# Hilo Thread-2, Episodio 122, Recompensa total: 14.800000000000082
# Hilo Thread-4, Episodio 110, Recompensa total: 36.9000000000004
# Hilo Thread-1, Episodio 105, Recompensa total: 0.7999999999999776
# Hilo Thread-4, Episodio 111, Recompensa total: 15.700000000000095
# Hilo Thread-1, Episodio 106, Recompensa total: 12.200000000000045
# Hilo Thread-3, Episodio 120, Recompensa total: 27.100000000000257
# Hilo Thread-4, Episodio 112, Recompensa total: 11.700000000000038
# Hilo Thread-2, Episodio 123, Recompensa total: 38.70000000000042
# Hilo Thread-3, Episodio 121, Recompensa total: 19.200000000000145
# Hilo Thread-1, Episodio 107, Recompensa total: 22.000000000000185
# Hilo Thread-4, Episodio 113, Recompensa total: 7.899999999999984
# Hilo Thread-2, Episodio 124, Recompensa total: 11.700000000000038
# Hilo Thread-4, Episodio 114, Recompensa total: 10.100000000000016
# Hilo Thread-1, Episodio 108, Recompensa total: 18.600000000000136
# Hilo Thread-3, Episodio 122, Recompensa total: 22.600000000000193
# Hilo Thread-1, Episodio 109, Recompensa total: 2.399999999999972
# Hilo Thread-3, Episodio 123, Recompensa total: 16.200000000000102
# Hilo Thread-4, Episodio 115, Recompensa total: 27.800000000000267
# Hilo Thread-2, Episodio 125, Recompensa total: 45.300000000000516
# Hilo Thread-1, Episodio 110, Recompensa total: 26.300000000000246
# Hilo Thread-2, Episodio 126, Recompensa total: 7.6999999999999815
# Hilo Thread-2, Episodio 127, Recompensa total: -0.8000000000000167
# Hilo Thread-4, Episodio 116, Recompensa total: 25.30000000000023
# Hilo Thread-2, Episodio 128, Recompensa total: -0.10000000000001918
# Hilo Thread-1, Episodio 111, Recompensa total: 10.500000000000021
# Hilo Thread-4, Episodio 117, Recompensa total: 2.4999999999999716
# Hilo Thread-3, Episodio 124, Recompensa total: 43.40000000000049
# Hilo Thread-1, Episodio 112, Recompensa total: 13.000000000000057
# Hilo Thread-2, Episodio 129, Recompensa total: 18.000000000000128
# Hilo Thread-1, Episodio 113, Recompensa total: 3.499999999999968
# Hilo Thread-4, Episodio 118, Recompensa total: 20.800000000000168
# Hilo Thread-2, Episodio 130, Recompensa total: 1.8999999999999737
# Hilo Thread-3, Episodio 125, Recompensa total: 27.800000000000267
# Hilo Thread-3, Episodio 126, Recompensa total: 0.9999999999999769
# Hilo Thread-3, Episodio 127, Recompensa total: 0.19999999999997975
# Hilo Thread-2, Episodio 131, Recompensa total: 23.300000000000203
# Hilo Thread-2, Episodio 132, Recompensa total: 0.39999999999997904
# Hilo Thread-2, Episodio 133, Recompensa total: -1.000000000000016
# Hilo Thread-3, Episodio 128, Recompensa total: 14.800000000000082
# Hilo Thread-4, Episodio 119, Recompensa total: 48.800000000000566
# Hilo Thread-3, Episodio 129, Recompensa total: 2.399999999999972
# Hilo Thread-4, Episodio 120, Recompensa total: 2.4999999999999716
# Hilo Thread-4, Episodio 121, Recompensa total: 0.0999999999999801
# Hilo Thread-2, Episodio 134, Recompensa total: 23.400000000000205
# Hilo Thread-3, Episodio 130, Recompensa total: 7.59999999999998
# Hilo Thread-1, Episodio 114, Recompensa total: 88.49999999999868
# Hilo Thread-4, Episodio 122, Recompensa total: 3.8999999999999666
# Hilo Thread-2, Episodio 135, Recompensa total: 4.1999999999999655
# Hilo Thread-1, Episodio 115, Recompensa total: -0.20000000000001883
# Hilo Thread-2, Episodio 136, Recompensa total: 4.799999999999963
# Hilo Thread-3, Episodio 131, Recompensa total: 21.70000000000018
# Hilo Thread-4, Episodio 123, Recompensa total: 24.200000000000216
# Hilo Thread-2, Episodio 137, Recompensa total: 15.400000000000091
# Hilo Thread-1, Episodio 116, Recompensa total: 36.100000000000385
# Hilo Thread-4, Episodio 124, Recompensa total: 14.300000000000075
# Hilo Thread-4, Episodio 125, Recompensa total: -0.10000000000001918
# Hilo Thread-3, Episodio 132, Recompensa total: 47.300000000000544
# Hilo Thread-1, Episodio 117, Recompensa total: 18.600000000000136
# Hilo Thread-4, Episodio 126, Recompensa total: 9.400000000000006
# Hilo Thread-4, Episodio 127, Recompensa total: -0.6000000000000174
# Hilo Thread-3, Episodio 133, Recompensa total: 8.199999999999989
# Hilo Thread-4, Episodio 128, Recompensa total: 21.900000000000183
# Hilo Thread-2, Episodio 138, Recompensa total: 76.99999999999933
# Hilo Thread-1, Episodio 118, Recompensa total: 39.80000000000044
# Hilo Thread-4, Episodio 129, Recompensa total: 0.7999999999999776
# Hilo Thread-4, Episodio 130, Recompensa total: 7.899999999999984
# Hilo Thread-2, Episodio 139, Recompensa total: 19.300000000000146
# Hilo Thread-3, Episodio 134, Recompensa total: 58.100000000000406
# Hilo Thread-4, Episodio 131, Recompensa total: 1.1999999999999762
# Hilo Thread-2, Episodio 140, Recompensa total: 7.6999999999999815
# Hilo Thread-3, Episodio 135, Recompensa total: 5.999999999999959
# Hilo Thread-4, Episodio 132, Recompensa total: 5.199999999999962
# Hilo Thread-4, Episodio 133, Recompensa total: 7.799999999999983
# Hilo Thread-1, Episodio 119, Recompensa total: 59.60000000000032
# Hilo Thread-2, Episodio 141, Recompensa total: 22.100000000000186
# Hilo Thread-4, Episodio 134, Recompensa total: 7.299999999999976
# Hilo Thread-3, Episodio 136, Recompensa total: 30.0000000000003
# Hilo Thread-1, Episodio 120, Recompensa total: 14.500000000000078
# Hilo Thread-4, Episodio 135, Recompensa total: -0.3000000000000185
# Hilo Thread-3, Episodio 137, Recompensa total: 3.9999999999999662
# Hilo Thread-1, Episodio 121, Recompensa total: -0.20000000000001883
# Hilo Thread-2, Episodio 142, Recompensa total: 22.30000000000019
